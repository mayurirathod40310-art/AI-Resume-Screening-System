# %% [markdown]
# # AI-Based Resume Screening System

# %% [markdown]
# The objective of this project is to develop an AI-based system that analyzes resumes and compares them with a given job description. The system extracts key skills from the resume, matches them with required job skills, calculates a matching score, and provides an explanation based on the level of match.

# %% [markdown]
# Install

# %%
# !pip install transformers langchain-core
# Out:
# Requirement already satisfied: transformers in c:\users\user victus\anaconda3\lib\site-packages (5.4.0)
# Requirement already satisfied: langchain-core in c:\users\user victus\anaconda3\lib\site-packages (1.2.28)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\user victus\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\user victus\anaconda3\lib\site-packages (from transformers) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\user victus\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\user victus\anaconda3\lib\site-packages (from transformers) (0.9.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\user victus\anaconda3\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user victus\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\user victus\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\users\user victus\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.0)
# Requirement already satisfied: certifi in c:\users\user victus\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\user victus\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\user victus\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\user victus\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user victus\anaconda3\lib\site-packages (from langchain-core) (0.7.30)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from langchain-core) (2.12.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user victus\anaconda3\lib\site-packages (from langchain-core) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user victus\anaconda3\lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\user victus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user victus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\user victus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user victus\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.2)
# Requirement already satisfied: colorama in c:\users\user victus\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user victus\appdata\roaming\python\python313\site-packages (from typer->transformers) (8.3.1)

# %% [markdown]
# import Libraries

# %%
from transformers import pipeline
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# Load Local Model

# %%
llm = pipeline("text-generation", model="distilgpt2")
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]

# %% [markdown]
# Resume and Job Description

# %%
resume = """
John Doe
Skills: Python, Machine Learning, SQL, Pandas, NumPy, Deep Learning
Experience: 2 years in Data Science projects including model building and data analysis
Tools: Jupyter, Scikit-learn, TensorFlow
"""

job_description = """
Looking for a Data Scientist with:
Python, Machine Learning, SQL, Pandas, NumPy
Experience in data analysis and model building
"""

# %% [markdown]
# Extract Function

# %%
def extract_info(resume_text):
    lines = resume_text.split("\n")
    
    skills = ""
    experience = ""
    tools = ""
    
    for line in lines:
        if "Skills:" in line:
            skills = line.replace("Skills:", "").strip()
        elif "Experience:" in line:
            experience = line.replace("Experience:", "").strip()
        elif "Tools:" in line:
            tools = line.replace("Tools:", "").strip()
    
    return {
        "skills": skills,
        "experience": experience,
        "tools": tools
    }

# %% [markdown]
# Score Function

# %%
def calculate_score(resume_data, job_description):
    jd_skills = ["Python", "Machine Learning", "SQL", "Pandas", "NumPy"]
    
    resume_skills = [skill.strip() for skill in resume_data["skills"].split(",")]
    
    match_count = 0
    
    for skill in jd_skills:
        if skill in resume_skills:
            match_count += 1
    
    score = (match_count / len(jd_skills)) * 100
    
    return score, match_count

# %% [markdown]
# Extract Data

# %%
data = extract_info(resume)

# %% [markdown]
# Calculate Score

# %%
score, match_count = calculate_score(data, job_description)

# %% [markdown]
# LLM Explanation

# %%
simple_prompt = f"""
Candidate Score: {score}

Skills: {data['skills']}

Job requires: Python, Machine Learning, SQL, Pandas, NumPy

Explain in 2 lines why this score is given.
"""

def generate_explanation(score, match_count):
    if score == 100:
        return "Candidate perfectly matches all required skills."
    elif score >= 70:
        return f"Candidate matches most required skills ({match_count} matched)."
    elif score >= 40:
        return f"Candidate matches some skills ({match_count} matched)."
    else:
        return "Candidate does not match required skills."

explanation = generate_explanation(score, match_count)

print("Matching Score:", score)
print("Explanation:", explanation)
# Out:
# Matching Score: 100.0
# Explanation: Candidate perfectly matches all required skills.
